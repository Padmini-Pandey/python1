# %% [markdown]
# <a href="https://colab.research.google.com/github/Padmini-Pandey/python1/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# program 1

# %%
fruits = ["Apple", "Banana", "Orange", "grapefruit", "Pineapple"]
print("2nd item:", fruits[1])
print("4th item:", fruits[3])
l=len(fruits)
fruits[l-1]="Mango"
print("Updated list:", fruits)
# Out:
# 2nd item: Banana
# 4th item: grapefruit
# Updated list: ['Apple', 'Banana', 'Orange', 'grapefruit', 'Mango']

# %% [markdown]
# program 2

# %%
a = []
for i in range(10):
    n = int(input("Enter integer: "))
    a[i]=
total = 0

for n in numbers:
    total = total + n

# Find average
average = total / 10

print("List:", numbers)
print("Sum:", total)
print("Average:", average)
